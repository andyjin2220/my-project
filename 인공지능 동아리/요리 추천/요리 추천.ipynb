# %%
import tensorflow as tf
from tensorflow.keras.applications import mobilenet_v2
from tensorflow.keras.preprocessing import image
import pandas as pd

# 1. MobileNetV2 모델 로드
model = mobilenet_v2.MobileNetV2(weights='imagenet')

# 2. 이미지 분석 함수
def analyze_image(image_path):
    """
    주어진 이미지에서 MobileNetV2로 객체를 탐지하고 상위 5개의 결과 반환
    """
    try:
        img = image.load_img(image_path, target_size=(224, 224))
        img_array = image.img_to_array(img)
        img_array = tf.expand_dims(img_array, axis=0)
        img_array = mobilenet_v2.preprocess_input(img_array)
        predictions = model.predict(img_array)
        decoded = tf.keras.applications.mobilenet_v2.decode_predictions(predictions, top=5)
        return [item[1] for item in decoded[0]]  # 클래스 이름 반환
    except Exception as e:
        print(f"Error analyzing image: {e}")
        return []

# 3. 요리 추천 함수
def recommend_recipes(ingredients):
    """
    탐지된 재료를 기반으로 추천 요리 반환 (두 개 이상의 재료가 만족되면 추천)
    """
    try:
        data = pd.read_csv('recipes.csv')  # 'recipes.csv' 파일 필요
        recommendations = []
        for _, row in data.iterrows():
            # 재료가 2개 이상 만족하는 경우 추천
            matching_ingredients = [ingredient for ingredient in ingredients if ingredient in row['ingredients']]
            if len(matching_ingredients) >= 2:
                recommendations.append(row['recipe_name'])
        if not recommendations:
            return ["No recipes found for the given ingredients."]
        return recommendations
    except FileNotFoundError:
        return ["Error: Recipe database (recipes.csv) not found."]


# 4. 실행 코드
if __name__ == "__main__":
    # 사용자가 업로드한 이미지 경로
    image_path = r'C:\Users\andyj\Desktop\project\인공지능 동아리\과일.jpg'  # 사용자가 업로드한 이미지 파일

    # 1. 이미지 분석
    ingredients = analyze_image(image_path)
    print("Detected Ingredients:", ingredients)

    # 2. 요리 추천
    if ingredients:
        recipes = recommend_recipes(ingredients)
        print("Recommended Recipes:", recipes)
        # 레시피 단계 출력
        data = pd.read_csv('recipes.csv')
        for recipe in recipes:
            print(f"Recipe: {recipe}")
            steps = data.loc[data['recipe_name'] == recipe, 'steps'].values
            if steps:
                for step in steps[0].split('. '):
                    print(step)
            else:
                print("No steps found for this recipe.")
    else:
        print("No ingredients detected.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Detected Ingredients: ['pineapple', 'banana', 'orange', 'lemon', 'custard_apple']
# Recommended Recipes: ['Fruit Salad']
# Recipe: Fruit Salad
# 1
# Chop apple, banana, and orange into small pieces
# 2
# Peel grapes
# 3
# Mix all fruits in a bowl
# 4
# Drizzle honey and lemon juice on top
# Stir well.

# %%
from tensorflow.keras.applications import mobilenet_v2
import numpy as np

# MobileNetV2 모델의 클래스 이름을 가져오기
decode_predictions = mobilenet_v2.decode_predictions

# ImageNet의 1000개 클래스 이름을 가져옵니다.
# 빈 배열로 패딩된 예시 입력을 사용하여 1000개의 클래스 이름을 추출합니다.
class_names = np.array([item[1] for item in decode_predictions(np.zeros((1, 1000)), top=1000)[0]])

# 전체 1000개의 클래스 출력
for i, class_name in enumerate(class_names):
    print(f"{i + 1}: {class_name}")
# Out:
# 1: toilet_tissue
# 2: sea_urchin
# 3: hog
# 4: zebra
# 5: sorrel
# 6: guinea_pig
# 7: beaver
# 8: marmot
# 9: fox_squirrel
# 10: porcupine
# 11: hamster
# 12: Angora
# 13: hare
# 14: wood_rabbit
# 15: sea_cucumber
# 16: starfish
# 17: cricket
# 18: lycaenid
# 19: sulphur_butterfly
# 20: cabbage_butterfly
# 21: monarch
# 22: ringlet
# 23: admiral
# 24: damselfly
# 25: dragonfly
# 26: lacewing
# 27: leafhopper
# 28: cicada
# 29: mantis
# 30: cockroach
# 31: wild_boar
# 32: warthog
# 33: hippopotamus
# 34: ox
# 35: baboon
# 36: patas
# 37: guenon
# 38: siamang
# 39: gibbon
# 40: chimpanzee
# 41: gorilla
# 42: orangutan
# 43: three-toed_sloth
# 44: armadillo
# 45: badger
# 46: skunk
# 47: otter
# 48: black-footed_ferret
# 49: polecat
# 50: mink
# 51: weasel
# 52: llama
# 53: Arabian_camel
# 54: gazelle
# 55: impala
# 56: hartebeest
# 57: ibex
# 58: bighorn
# 59: ram
# 60: bison
# 61: water_buffalo
# 62: walking_stick
# 63: grasshopper
# 64: ear
# 65: toy_poodle
# 66: kit_fox
# 67: red_fox
# 68: hyena
# 69: African_hunting_dog
# 70: dhole
# 71: dingo
# 72: coyote
# 73: red_wolf
# 74: white_wolf
# 75: timber_wolf
# 76: Mexican_hairless
# 77: standard_poodle
# 78: miniature_poodle
# 79: Cardigan
# 80: ant
# 81: Pembroke
# 82: Brabancon_griffon
# 83: keeshond
# 84: chow
# 85: Pomeranian
# 86: Samoyed
# 87: Great_Pyrenees
# 88: Newfoundland
# 89: Leonberg
# 90: pug
# 91: basenji
# 92: affenpinscher
# 93: dalmatian
# 94: Arctic_fox
# 95: grey_fox
# 96: tabby
# 97: tiger_cat
# 98: bee
# 99: fly
# 100: weevil
# 101: rhinoceros_beetle
# 102: dung_beetle
# 103: leaf_beetle
# 104: long-horned_beetle
# 105: ground_beetle
# 106: ladybug
# 107: tiger_beetle
# 108: meerkat
# 109: mongoose
# 110: sloth_bear
# 111: ice_bear
# 112: American_black_bear
# 113: brown_bear
# 114: cheetah
# 115: tiger
# 116: lion
# 117: jaguar
# 118: snow_leopard
# 119: leopard
# 120: lynx
# 121: cougar
# 122: Egyptian_cat
# 123: Siamese_cat
# 124: Persian_cat
# 125: macaque
# 126: langur
# 127: colobus
# 128: bookcase
# 129: bullet_train
# 130: bulletproof_vest
# 131: buckle
# 132: bucket
# 133: broom
# 134: breastplate
# 135: breakwater
# 136: brassiere
# 137: brass
# 138: bow_tie
# 139: bow
# 140: bottlecap
# 141: bookshop
# 142: bonnet
# 143: proboscis_monkey
# 144: bolo_tie
# 145: bobsled
# 146: boathouse
# 147: birdhouse
# 148: binoculars
# 149: binder
# 150: bikini
# 151: bicycle-built-for-two
# 152: bib
# 153: bell_cote
# 154: beer_glass
# 155: beer_bottle
# 156: bearskin
# 157: butcher_shop
# 158: cab
# 159: caldron
# 160: candle
# 161: church
# 162: Christmas_stocking
# 163: china_cabinet
# 164: chime
# 165: chiffonier
# 166: chest
# 167: chain_saw
# 168: chain_mail
# 169: chainlink_fence
# 170: chain
# 171: cellular_telephone
# 172: cello
# 173: CD_player
# 174: catamaran
# 175: castle
# 176: cassette_player
# 177: cassette
# 178: cash_machine
# 179: car_wheel
# 180: carton
# 181: carpenter's_kit
# 182: carousel
# 183: car_mirror
# 184: cardigan
# 185: can_opener
# 186: canoe
# 187: cannon
# 188: beaker
# 189: beacon
# 190: beach_wagon
# 191: airship
# 192: aircraft_carrier
# 193: acoustic_guitar
# 194: accordion
# 195: academic_gown
# 196: abaya
# 197: abacus
# 198: puffer
# 199: lionfish
# 200: gar
# 201: sturgeon
# 202: anemone_fish
# 203: rock_beauty
# 204: coho
# 205: eel
# 206: barracouta
# 207: giant_panda
# 208: lesser_panda
# 209: African_elephant
# 210: Indian_elephant
# 211: indri
# 212: Madagascar_cat
# 213: squirrel_monkey
# 214: spider_monkey
# 215: titi
# 216: howler_monkey
# 217: capuchin
# 218: marmoset
# 219: airliner
# 220: altar
# 221: bathtub
# 222: ambulance
# 223: bath_towel
# 224: bathing_cap
# 225: bassoon
# 226: bassinet
# 227: basketball
# 228: baseball
# 229: barrow
# 230: barrel
# 231: barometer
# 232: barn
# 233: barbershop
# 234: barber_chair
# 235: barbell
# 236: bannister
# 237: banjo
# 238: Band_Aid
# 239: ballpoint
# 240: balloon
# 241: balance_beam
# 242: bakery
# 243: backpack
# 244: assault_rifle
# 245: ashcan
# 246: apron
# 247: apiary
# 248: analog_clock
# 249: amphibian
# 250: Siberian_husky
# 251: malamute
# 252: Eskimo_dog
# 253: wolf_spider
# 254: lorikeet
# 255: sulphur-crested_cockatoo
# 256: macaw
# 257: African_grey
# 258: partridge
# 259: quail
# 260: peacock
# 261: prairie_chicken
# 262: ruffed_grouse
# 263: ptarmigan
# 264: black_grouse
# 265: centipede
# 266: tick
# 267: tarantula
# 268: spiny_lobster
# 269: black_widow
# 270: garden_spider
# 271: barn_spider
# 272: black_and_gold_garden_spider
# 273: scorpion
# 274: harvestman
# 275: trilobite
# 276: sidewinder
# 277: diamondback
# 278: horned_viper
# 279: sea_snake
# 280: green_mamba
# 281: Indian_cobra
# 282: coucal
# 283: bee_eater
# 284: hornbill
# 285: hummingbird
# 286: king_crab
# 287: fiddler_crab
# 288: rock_crab
# 289: Dungeness_crab
# 290: chambered_nautilus
# 291: chiton
# 292: sea_slug
# 293: slug
# 294: snail
# 295: conch
# 296: nematode
# 297: flatworm
# 298: brain_coral
# 299: sea_anemone
# 300: jellyfish
# 301: wombat
# 302: koala
# 303: wallaby
# 304: platypus
# 305: echidna
# 306: tusker
# 307: black_swan
# 308: goose
# 309: red-breasted_merganser
# 310: drake
# 311: toucan
# 312: jacamar
# 313: rock_python
# 314: boa_constrictor
# 315: night_snake
# 316: axolotl
# 317: eft
# 318: common_newt
# 319: European_fire_salamander
# 320: great_grey_owl
# 321: vulture
# 322: bald_eagle
# 323: kite
# 324: water_ouzel
# 325: chickadee
# 326: magpie
# 327: jay
# 328: bulbul
# 329: robin
# 330: indigo_bunting
# 331: junco
# 332: house_finch
# 333: goldfinch
# 334: brambling
# 335: ostrich
# 336: hen
# 337: cock
# 338: stingray
# 339: electric_ray
# 340: hammerhead
# 341: tiger_shark
# 342: great_white_shark
# 343: goldfish
# 344: spotted_salamander
# 345: bullfrog
# 346: vine_snake
# 347: tree_frog
# 348: water_snake
# 349: garter_snake
# 350: king_snake
# 351: green_snake
# 352: hognose_snake
# 353: ringneck_snake
# 354: thunder_snake
# 355: triceratops
# 356: American_alligator
# 357: African_crocodile
# 358: Komodo_dragon
# 359: African_chameleon
# 360: green_lizard
# 361: Gila_monster
# 362: alligator_lizard
# 363: frilled_lizard
# 364: agama
# 365: whiptail
# 366: American_chameleon
# 367: common_iguana
# 368: banded_gecko
# 369: box_turtle
# 370: terrapin
# 371: mud_turtle
# 372: leatherback_turtle
# 373: loggerhead
# 374: tailed_frog
# 375: American_lobster
# 376: crayfish
# 377: Saint_Bernard
# 378: soft-coated_wheaten_terrier
# 379: Brittany_spaniel
# 380: Gordon_setter
# 381: Irish_setter
# 382: English_setter
# 383: vizsla
# 384: German_short-haired_pointer
# 385: Chesapeake_Bay_retriever
# 386: Labrador_retriever
# 387: golden_retriever
# 388: curly-coated_retriever
# 389: flat-coated_retriever
# 390: Lhasa
# 391: West_Highland_white_terrier
# 392: silky_terrier
# 393: hermit_crab
# 394: Tibetan_terrier
# 395: Scotch_terrier
# 396: standard_schnauzer
# 397: giant_schnauzer
# 398: miniature_schnauzer
# 399: Boston_bull
# 400: Dandie_Dinmont
# 401: Australian_terrier
# 402: cairn
# 403: Airedale
# 404: Sealyham_terrier
# 405: Lakeland_terrier
# 406: wire-haired_fox_terrier
# 407: clumber
# 408: English_springer
# 409: Welsh_springer_spaniel
# 410: cocker_spaniel
# 411: Great_Dane
# 412: French_bulldog
# 413: Tibetan_mastiff
# 414: bull_mastiff
# 415: boxer
# 416: EntleBucher
# 417: Appenzeller
# 418: Bernese_mountain_dog
# 419: Greater_Swiss_Mountain_dog
# 420: miniature_pinscher
# 421: Doberman
# 422: German_shepherd
# 423: Rottweiler
# 424: Bouvier_des_Flandres
# 425: Border_collie
# 426: collie
# 427: Shetland_sheepdog
# 428: Old_English_sheepdog
# 429: komondor
# 430: kelpie
# 431: briard
# 432: malinois
# 433: groenendael
# 434: schipperke
# 435: kuvasz
# 436: Irish_water_spaniel
# 437: Sussex_spaniel
# 438: Yorkshire_terrier
# 439: Norwich_terrier
# 440: Norfolk_terrier
# 441: Pekinese
# 442: Japanese_spaniel
# 443: Chihuahua
# 444: sea_lion
# 445: dugong
# 446: killer_whale
# 447: grey_whale
# 448: albatross
# 449: king_penguin
# 450: pelican
# 451: oystercatcher
# 452: dowitcher
# 453: redshank
# 454: red-backed_sandpiper
# 455: ruddy_turnstone
# 456: bustard
# 457: American_coot
# 458: European_gallinule
# 459: limpkin
# 460: crane
# 461: bittern
# 462: American_egret
# 463: little_blue_heron
# 464: flamingo
# 465: spoonbill
# 466: black_stork
# 467: white_stork
# 468: isopod
# 469: Maltese_dog
# 470: Shih-Tzu
# 471: Irish_terrier
# 472: Blenheim_spaniel
# 473: Kerry_blue_terrier
# 474: Border_terrier
# 475: Bedlington_terrier
# 476: American_Staffordshire_terrier
# 477: Staffordshire_bullterrier
# 478: Weimaraner
# 479: Scottish_deerhound
# 480: Saluki
# 481: otterhound
# 482: Norwegian_elkhound
# 483: Ibizan_hound
# 484: whippet
# 485: Italian_greyhound
# 486: Irish_wolfhound
# 487: borzoi
# 488: redbone
# 489: English_foxhound
# 490: Walker_hound
# 491: black-and-tan_coonhound
# 492: bluetick
# 493: bloodhound
# 494: beagle
# 495: basset
# 496: Afghan_hound
# 497: Rhodesian_ridgeback
# 498: toy_terrier
# 499: papillon
# 500: cinema
# 501: cleaver
# 502: cliff_dwelling
# 503: strainer
# 504: sweatshirt
# 505: swab
# 506: suspension_bridge
# 507: sunscreen
# 508: sunglasses
# 509: sunglass
# 510: sundial
# 511: suit
# 512: submarine
# 513: stupa
# 514: studio_couch
# 515: stretcher
# 516: streetcar
# 517: stove
# 518: trolleybus
# 519: stopwatch
# 520: stone_wall
# 521: stole
# 522: stethoscope
# 523: steel_drum
# 524: steel_arch_bridge
# 525: steam_locomotive
# 526: stage
# 527: spotlight
# 528: sports_car
# 529: spindle
# 530: spider_web
# 531: speedboat
# 532: swimming_trunks
# 533: swing
# 534: switch
# 535: syringe
# 536: tripod
# 537: trimaran
# 538: tricycle
# 539: trench_coat
# 540: tray
# 541: trailer_truck
# 542: tractor
# 543: toyshop
# 544: tow_truck
# 545: totem_pole
# 546: torch
# 547: toilet_seat
# 548: tobacco_shop
# 549: toaster
# 550: tile_roof
# 551: throne
# 552: thresher
# 553: thimble
# 554: theater_curtain
# 555: thatch
# 556: tennis_ball
# 557: television
# 558: teddy
# 559: teapot
# 560: tape_player
# 561: tank
# 562: table_lamp
# 563: spatula
# 564: space_shuttle
# 565: space_heater
# 566: schooner
# 567: scale
# 568: scabbard
# 569: sax
# 570: sarong
# 571: sandal
# 572: saltshaker
# 573: safety_pin
# 574: safe
# 575: running_shoe
# 576: rule
# 577: rugby_ball
# 578: rubber_eraser
# 579: rotisserie
# 580: rocking_chair
# 581: rifle
# 582: revolver
# 583: restaurant
# 584: remote_control
# 585: refrigerator
# 586: reflex_camera
# 587: reel
# 588: recreational_vehicle
# 589: rain_barrel
# 590: radio_telescope
# 591: radio
# 592: radiator
# 593: racket
# 594: school_bus
# 595: scoreboard
# 596: space_bar
# 597: screen
# 598: soup_bowl
# 599: sombrero
# 600: solar_dish
# 601: sock
# 602: soccer_ball
# 603: soap_dispenser
# 604: snowplow
# 605: snowmobile
# 606: snorkel
# 607: slot
# 608: sliding_door
# 609: slide_rule
# 610: sleeping_bag
# 611: ski_mask
# 612: ski
# 613: shower_curtain
# 614: shower_cap
# 615: shovel
# 616: shopping_cart
# 617: shopping_basket
# 618: shoji
# 619: shoe_shop
# 620: shield
# 621: sewing_machine
# 622: seat_belt
# 623: screwdriver
# 624: screw
# 625: triumphal_arch
# 626: trombone
# 627: quilt
# 628: pineapple
# 629: red_wine
# 630: burrito
# 631: potpie
# 632: pizza
# 633: meat_loaf
# 634: dough
# 635: chocolate_sauce
# 636: carbonara
# 637: hay
# 638: pomegranate
# 639: custard_apple
# 640: jackfruit
# 641: banana
# 642: fig
# 643: tub
# 644: lemon
# 645: orange
# 646: strawberry
# 647: Granny_Smith
# 648: mushroom
# 649: cardoon
# 650: bell_pepper
# 651: artichoke
# 652: cucumber
# 653: butternut_squash
# 654: acorn_squash
# 655: spaghetti_squash
# 656: zucchini
# 657: espresso
# 658: cup
# 659: eggnog
# 660: alp
# 661: bolete
# 662: hen-of-the-woods
# 663: earthstar
# 664: stinkhorn
# 665: gyromitra
# 666: agaric
# 667: coral_fungus
# 668: buckeye
# 669: hip
# 670: acorn
# 671: corn
# 672: yellow_lady's_slipper
# 673: daisy
# 674: rapeseed
# 675: scuba_diver
# 676: groom
# 677: ballplayer
# 678: volcano
# 679: valley
# 680: seashore
# 681: sandbar
# 682: promontory
# 683: lakeside
# 684: geyser
# 685: coral_reef
# 686: cliff
# 687: bubble
# 688: cauliflower
# 689: broccoli
# 690: head_cabbage
# 691: window_shade
# 692: wig
# 693: whistle
# 694: whiskey_jug
# 695: water_tower
# 696: water_jug
# 697: water_bottle
# 698: washer
# 699: washbasin
# 700: warplane
# 701: wardrobe
# 702: wallet
# 703: wall_clock
# 704: waffle_iron
# 705: volleyball
# 706: violin
# 707: viaduct
# 708: vestment
# 709: vending_machine
# 710: velvet
# 711: vault
# 712: vase
# 713: vacuum
# 714: upright
# 715: unicycle
# 716: umbrella
# 717: typewriter_keyboard
# 718: turnstile
# 719: window_screen
# 720: Windsor_tie
# 721: mashed_potato
# 722: wine_bottle
# 723: hotdog
# 724: cheeseburger
# 725: pretzel
# 726: bagel
# 727: French_loaf
# 728: ice_lolly
# 729: ice_cream
# 730: trifle
# 731: hot_pot
# 732: consomme
# 733: guacamole
# 734: plate
# 735: menu
# 736: book_jacket
# 737: traffic_light
# 738: street_sign
# 739: crossword_puzzle
# 740: comic_book
# 741: web_site
# 742: yurt
# 743: yawl
# 744: wreck
# 745: worm_fence
# 746: wool
# 747: wooden_spoon
# 748: wok
# 749: wing
# 750: racer
# 751: quill
# 752: cloak
# 753: gown
# 754: handkerchief
# 755: hand-held_computer
# 756: hand_blower
# 757: hamper
# 758: hammer
# 759: half_track
# 760: hair_spray
# 761: hair_slide
# 762: guillotine
# 763: grocery_store
# 764: grille
# 765: greenhouse
# 766: grand_piano
# 767: gong
# 768: library
# 769: gondola
# 770: golfcart
# 771: golf_ball
# 772: go-kart
# 773: goblet
# 774: gas_pump
# 775: gasmask
# 776: garbage_truck
# 777: fur_coat
# 778: frying_pan
# 779: French_horn
# 780: freight_car
# 781: four-poster
# 782: hard_disc
# 783: harmonica
# 784: harp
# 785: harvester
# 786: lens_cap
# 787: lawn_mower
# 788: laptop
# 789: lampshade
# 790: ladle
# 791: lab_coat
# 792: knot
# 793: knee_pad
# 794: kimono
# 795: joystick
# 796: jinrikisha
# 797: jigsaw_puzzle
# 798: jersey
# 799: jeep
# 800: jean
# 801: jack-o'-lantern
# 802: iron
# 803: iPod
# 804: hourglass
# 805: horse_cart
# 806: horizontal_bar
# 807: hoopskirt
# 808: hook
# 809: honeycomb
# 810: home_theater
# 811: holster
# 812: hatchet
# 813: fountain_pen
# 814: fountain
# 815: forklift
# 816: digital_clock
# 817: dial_telephone
# 818: desktop_computer
# 819: desk
# 820: dam
# 821: cuirass
# 822: crutch
# 823: croquet_ball
# 824: Crock_Pot
# 825: crib
# 826: crate
# 827: crash_helmet
# 828: crane
# 829: cradle
# 830: cowboy_hat
# 831: cowboy_boot
# 832: cornet
# 833: corkscrew
# 834: convertible
# 835: container_ship
# 836: confectionery
# 837: computer_keyboard
# 838: combination_lock
# 839: coil
# 840: coffeepot
# 841: coffee_mug
# 842: cocktail_shaker
# 843: clog
# 844: diaper
# 845: digital_watch
# 846: football_helmet
# 847: dining_table
# 848: folding_chair
# 849: flute
# 850: flagpole
# 851: fire_screen
# 852: fire_engine
# 853: fireboat
# 854: file
# 855: feather_boa
# 856: face_powder
# 857: espresso_maker
# 858: envelope
# 859: entertainment_center
# 860: electric_locomotive
# 861: electric_guitar
# 862: electric_fan
# 863: Dutch_oven
# 864: dumbbell
# 865: drumstick
# 866: drum
# 867: drilling_platform
# 868: doormat
# 869: dome
# 870: dogsled
# 871: dock
# 872: disk_brake
# 873: dishwasher
# 874: dishrag
# 875: letter_opener
# 876: lifeboat
# 877: purse
# 878: park_bench
# 879: picket_fence
# 880: pickelhaube
# 881: pick
# 882: photocopier
# 883: Petri_dish
# 884: perfume
# 885: pencil_sharpener
# 886: pencil_box
# 887: pedestal
# 888: pay-phone
# 889: patio
# 890: passenger_car
# 891: parking_meter
# 892: parallel_bars
# 893: lighter
# 894: parachute
# 895: paper_towel
# 896: panpipe
# 897: palace
# 898: pajama
# 899: paintbrush
# 900: padlock
# 901: paddlewheel
# 902: paddle
# 903: packet
# 904: oxygen_mask
# 905: oxcart
# 906: overskirt
# 907: pickup
# 908: pier
# 909: piggy_bank
# 910: pill_bottle
# 911: punching_bag
# 912: puck
# 913: projector
# 914: projectile
# 915: prison
# 916: printer
# 917: prayer_rug
# 918: power_drill
# 919: potter's_wheel
# 920: pot
# 921: pop_bottle
# 922: pool_table
# 923: poncho
# 924: police_van
# 925: pole
# 926: Polaroid_camera
# 927: plunger
# 928: plow
# 929: plate_rack
# 930: plastic_bag
# 931: planetarium
# 932: plane
# 933: pitcher
# 934: pirate
# 935: pinwheel
# 936: ping-pong_ball
# 937: pillow
# 938: oscilloscope
# 939: organ
# 940: oil_filter
# 941: miniskirt
# 942: milk_can
# 943: military_uniform
# 944: microwave
# 945: microphone
# 946: megalith
# 947: medicine_chest
# 948: measuring_cup
# 949: maze
# 950: maypole
# 951: matchstick
# 952: mask
# 953: marimba
# 954: maraca
# 955: manhole_cover
# 956: maillot
# 957: maillot
# 958: mailbox
# 959: mailbag
# 960: magnetic_compass
# 961: lumbermill
# 962: loupe
# 963: loudspeaker
# 964: lotion
# 965: Loafer
# 966: lipstick
# 967: liner
# 968: limousine
# 969: minibus
# 970: minivan
# 971: odometer
# 972: missile
# 973: ocarina
# 974: oboe
# 975: obelisk
# 976: notebook
# 977: nipple
# 978: necklace
# 979: neck_brace
# 980: nail
# 981: muzzle
# 982: moving_van
# 983: mousetrap
# 984: mouse
# 985: mountain_tent
# 986: mountain_bike
# 987: motor_scooter
# 988: mosquito_net
# 989: mosque
# 990: mortarboard
# 991: mortar
# 992: moped
# 993: monitor
# 994: monastery
# 995: modem
# 996: Model_T
# 997: mobile_home
# 998: mixing_bowl
# 999: mitten
# 1000: tench
